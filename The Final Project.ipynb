# %% [markdown]
# # Importing Libiraries

# %%
import numpy as np  # for math operations
import pandas as pd # for reading dataset
import matplotlib.pyplot as plt    #Library for graph
import seaborn as sns     #Library for graph
from sklearn.model_selection import train_test_split #to split data into train and test
from sklearn.preprocessing import StandardScaler # to scale the data (between 0 and 1)
from sklearn.tree import DecisionTreeClassifier  # to use decision tree
from sklearn import metrics
from sklearn.metrics import accuracy_score     # to get accuracy score

# %% [markdown]
# # Loading data

# %%
path =  r'C:\Users\usama\Desktop\card_transdata.csv'

data= pd.read_csv(path)

# %% [markdown]
# # Data Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   distance_from_home              1000000 non-null  float64
#  1   distance_from_last_transaction  1000000 non-null  float64
#  2   ratio_to_median_purchase_price  1000000 non-null  float64
#  3   repeat_retailer                 1000000 non-null  int64
#  4   used_chip                       1000000 non-null  int64
#  5   used_pin_number                 1000000 non-null  int64
#  6   online_order                    1000000 non-null  int64
#  7   fraud                           1000000 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 61.0 MB

# %%
print("Dimensions are : ", data.shape) #to print data dimensions
# Out:
# Dimensions are :  (1000000, 8)

# %%
data.head().style.set_properties(**{'background-color': 'black', 'color': 'lawngreen', 'border-color': 'Black'}) # printing the first 5 rows
# Out:
# <style type="text/css">
# #T_23dda_row0_col0, #T_23dda_row0_col1, #T_23dda_row0_col2, #T_23dda_row0_col3, #T_23dda_row0_col4, #T_23dda_row0_col5, #T_23dda_row0_col6, #T_23dda_row0_col7, #T_23dda_row1_col0, #T_23dda_row1_col1, #T_23dda_row1_col2, #T_23dda_row1_col3, #T_23dda_row1_col4, #T_23dda_row1_col5, #T_23dda_row1_col6, #T_23dda_row1_col7, #T_23dda_row2_col0, #T_23dda_row2_col1, #T_23dda_row2_col2, #T_23dda_row2_col3, #T_23dda_row2_col4, #T_23dda_row2_col5, #T_23dda_row2_col6, #T_23dda_row2_col7, #T_23dda_row3_col0, #T_23dda_row3_col1, #T_23dda_row3_col2, #T_23dda_row3_col3, #T_23dda_row3_col4, #T_23dda_row3_col5, #T_23dda_row3_col6, #T_23dda_row3_col7, #T_23dda_row4_col0, #T_23dda_row4_col1, #T_23dda_row4_col2, #T_23dda_row4_col3, #T_23dda_row4_col4, #T_23dda_row4_col5, #T_23dda_row4_col6, #T_23dda_row4_col7 {
#   background-color: black;
#   color: lawngreen;
#   border-color: Black;
# }
# </style>
# <table id="T_23dda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23dda_level0_col0" class="col_heading level0 col0" >distance_from_home</th>
#       <th id="T_23dda_level0_col1" class="col_heading level0 col1" >distance_from_last_transaction</th>
#       <th id="T_23dda_level0_col2" class="col_heading level0 col2" >ratio_to_median_purchase_price</th>
#       <th id="T_23dda_level0_col3" class="col_heading level0 col3" >repeat_retailer</th>
#       <th id="T_23dda_level0_col4" class="col_heading level0 col4" >used_chip</th>
#       <th id="T_23dda_level0_col5" class="col_heading level0 col5" >used_pin_number</th>
#       <th id="T_23dda_level0_col6" class="col_heading level0 col6" >online_order</th>
#       <th id="T_23dda_level0_col7" class="col_heading level0 col7" >fraud</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23dda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23dda_row0_col0" class="data row0 col0" >57.877857</td>
#       <td id="T_23dda_row0_col1" class="data row0 col1" >0.311140</td>
#       <td id="T_23dda_row0_col2" class="data row0 col2" >1.945940</td>
#       <td id="T_23dda_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_23dda_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_23dda_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_23dda_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_23dda_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_23dda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23dda_row1_col0" class="data row1 col0" >10.829943</td>
#       <td id="T_23dda_row1_col1" class="data row1 col1" >0.175592</td>
#       <td id="T_23dda_row1_col2" class="data row1 col2" >1.294219</td>
#       <td id="T_23dda_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_23dda_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_23dda_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_23dda_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_23dda_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_23dda_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23dda_row2_col0" class="data row2 col0" >5.091079</td>
#       <td id="T_23dda_row2_col1" class="data row2 col1" >0.805153</td>
#       <td id="T_23dda_row2_col2" class="data row2 col2" >0.427715</td>
#       <td id="T_23dda_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_23dda_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_23dda_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_23dda_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_23dda_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_23dda_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23dda_row3_col0" class="data row3 col0" >2.247564</td>
#       <td id="T_23dda_row3_col1" class="data row3 col1" >5.600044</td>
#       <td id="T_23dda_row3_col2" class="data row3 col2" >0.362663</td>
#       <td id="T_23dda_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_23dda_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_23dda_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_23dda_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_23dda_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_23dda_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23dda_row4_col0" class="data row4 col0" >44.190936</td>
#       <td id="T_23dda_row4_col1" class="data row4 col1" >0.566486</td>
#       <td id="T_23dda_row4_col2" class="data row4 col2" >2.222767</td>
#       <td id="T_23dda_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_23dda_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_23dda_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_23dda_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_23dda_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.describe().T.style.set_properties(**{'background-color': 'black', 'color': 'lawngreen', 'border-color': 'Black'}) #describing data
# Out:
# <style type="text/css">
# #T_43285_row0_col0, #T_43285_row0_col1, #T_43285_row0_col2, #T_43285_row0_col3, #T_43285_row0_col4, #T_43285_row0_col5, #T_43285_row0_col6, #T_43285_row0_col7, #T_43285_row1_col0, #T_43285_row1_col1, #T_43285_row1_col2, #T_43285_row1_col3, #T_43285_row1_col4, #T_43285_row1_col5, #T_43285_row1_col6, #T_43285_row1_col7, #T_43285_row2_col0, #T_43285_row2_col1, #T_43285_row2_col2, #T_43285_row2_col3, #T_43285_row2_col4, #T_43285_row2_col5, #T_43285_row2_col6, #T_43285_row2_col7, #T_43285_row3_col0, #T_43285_row3_col1, #T_43285_row3_col2, #T_43285_row3_col3, #T_43285_row3_col4, #T_43285_row3_col5, #T_43285_row3_col6, #T_43285_row3_col7, #T_43285_row4_col0, #T_43285_row4_col1, #T_43285_row4_col2, #T_43285_row4_col3, #T_43285_row4_col4, #T_43285_row4_col5, #T_43285_row4_col6, #T_43285_row4_col7, #T_43285_row5_col0, #T_43285_row5_col1, #T_43285_row5_col2, #T_43285_row5_col3, #T_43285_row5_col4, #T_43285_row5_col5, #T_43285_row5_col6, #T_43285_row5_col7, #T_43285_row6_col0, #T_43285_row6_col1, #T_43285_row6_col2, #T_43285_row6_col3, #T_43285_row6_col4, #T_43285_row6_col5, #T_43285_row6_col6, #T_43285_row6_col7, #T_43285_row7_col0, #T_43285_row7_col1, #T_43285_row7_col2, #T_43285_row7_col3, #T_43285_row7_col4, #T_43285_row7_col5, #T_43285_row7_col6, #T_43285_row7_col7 {
#   background-color: black;
#   color: lawngreen;
#   border-color: Black;
# }
# </style>
# <table id="T_43285">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43285_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_43285_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_43285_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_43285_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_43285_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_43285_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_43285_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_43285_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43285_level0_row0" class="row_heading level0 row0" >distance_from_home</th>
#       <td id="T_43285_row0_col0" class="data row0 col0" >1000000.000000</td>
#       <td id="T_43285_row0_col1" class="data row0 col1" >26.628792</td>
#       <td id="T_43285_row0_col2" class="data row0 col2" >65.390784</td>
#       <td id="T_43285_row0_col3" class="data row0 col3" >0.004874</td>
#       <td id="T_43285_row0_col4" class="data row0 col4" >3.878008</td>
#       <td id="T_43285_row0_col5" class="data row0 col5" >9.967760</td>
#       <td id="T_43285_row0_col6" class="data row0 col6" >25.743985</td>
#       <td id="T_43285_row0_col7" class="data row0 col7" >10632.723670</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row1" class="row_heading level0 row1" >distance_from_last_transaction</th>
#       <td id="T_43285_row1_col0" class="data row1 col0" >1000000.000000</td>
#       <td id="T_43285_row1_col1" class="data row1 col1" >5.036519</td>
#       <td id="T_43285_row1_col2" class="data row1 col2" >25.843093</td>
#       <td id="T_43285_row1_col3" class="data row1 col3" >0.000118</td>
#       <td id="T_43285_row1_col4" class="data row1 col4" >0.296671</td>
#       <td id="T_43285_row1_col5" class="data row1 col5" >0.998650</td>
#       <td id="T_43285_row1_col6" class="data row1 col6" >3.355748</td>
#       <td id="T_43285_row1_col7" class="data row1 col7" >11851.104560</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row2" class="row_heading level0 row2" >ratio_to_median_purchase_price</th>
#       <td id="T_43285_row2_col0" class="data row2 col0" >1000000.000000</td>
#       <td id="T_43285_row2_col1" class="data row2 col1" >1.824182</td>
#       <td id="T_43285_row2_col2" class="data row2 col2" >2.799589</td>
#       <td id="T_43285_row2_col3" class="data row2 col3" >0.004399</td>
#       <td id="T_43285_row2_col4" class="data row2 col4" >0.475673</td>
#       <td id="T_43285_row2_col5" class="data row2 col5" >0.997717</td>
#       <td id="T_43285_row2_col6" class="data row2 col6" >2.096370</td>
#       <td id="T_43285_row2_col7" class="data row2 col7" >267.802942</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row3" class="row_heading level0 row3" >repeat_retailer</th>
#       <td id="T_43285_row3_col0" class="data row3 col0" >1000000.000000</td>
#       <td id="T_43285_row3_col1" class="data row3 col1" >0.881536</td>
#       <td id="T_43285_row3_col2" class="data row3 col2" >0.323157</td>
#       <td id="T_43285_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_43285_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_43285_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_43285_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_43285_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row4" class="row_heading level0 row4" >used_chip</th>
#       <td id="T_43285_row4_col0" class="data row4 col0" >1000000.000000</td>
#       <td id="T_43285_row4_col1" class="data row4 col1" >0.350399</td>
#       <td id="T_43285_row4_col2" class="data row4 col2" >0.477095</td>
#       <td id="T_43285_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_43285_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_43285_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_43285_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_43285_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row5" class="row_heading level0 row5" >used_pin_number</th>
#       <td id="T_43285_row5_col0" class="data row5 col0" >1000000.000000</td>
#       <td id="T_43285_row5_col1" class="data row5 col1" >0.100608</td>
#       <td id="T_43285_row5_col2" class="data row5 col2" >0.300809</td>
#       <td id="T_43285_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_43285_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_43285_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_43285_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_43285_row5_col7" class="data row5 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row6" class="row_heading level0 row6" >online_order</th>
#       <td id="T_43285_row6_col0" class="data row6 col0" >1000000.000000</td>
#       <td id="T_43285_row6_col1" class="data row6 col1" >0.650552</td>
#       <td id="T_43285_row6_col2" class="data row6 col2" >0.476796</td>
#       <td id="T_43285_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_43285_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_43285_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_43285_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_43285_row6_col7" class="data row6 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43285_level0_row7" class="row_heading level0 row7" >fraud</th>
#       <td id="T_43285_row7_col0" class="data row7 col0" >1000000.000000</td>
#       <td id="T_43285_row7_col1" class="data row7 col1" >0.087403</td>
#       <td id="T_43285_row7_col2" class="data row7 col2" >0.282425</td>
#       <td id="T_43285_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_43285_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_43285_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_43285_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_43285_row7_col7" class="data row7 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fraud = data[data['fraud'].isin([1])]     #Getting all one's togther
not_fraud = data[data['fraud'].isin([0])]    #Getting all zero's togther
print('Fraud data are : ')
print(fraud)
print('............................................................................................................................................................................................................................')
print('Not fraud data are: ')
print(not_fraud)
# Out:
# Fraud data are :
#         distance_from_home  distance_from_last_transaction  \
# 13                2.131956                       56.372401
# 24                3.803057                       67.241081
# 29               15.694986                      175.989182
# 35               26.711462                        1.552008
# 36               10.664474                        1.565769
# ...                    ...                             ...
# 999908           45.296658                        0.882736
# 999916          167.139756                        0.282253
# 999919          124.640118                        0.004416
# 999939           51.412900                        3.429330
# 999949           15.724799                        1.875906
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 13                            6.358667                1          0
# 24                            1.872950                1          0
# 29                            0.855623                1          0
# 35                            4.603601                1          1
# 36                            4.886521                1          0
# ...                                ...              ...        ...
# 999908                        8.856861                1          0
# 999916                        0.308468                1          0
# 999919                        0.434885                1          0
# 999939                       29.914254                1          0
# 999949                       11.009366                1          1
#
#         used_pin_number  online_order  fraud
# 13                    0             1      1
# 24                    0             1      1
# 29                    0             1      1
# 35                    0             1      1
# 36                    0             1      1
# ...                 ...           ...    ...
# 999908                0             1      1
# 999916                0             1      1
# 999919                0             1      1
# 999939                0             1      1
# 999949                0             1      1
#
# [87403 rows x 8 columns]
# ............................................................................................................................................................................................................................
# Not fraud data are:
#         distance_from_home  distance_from_last_transaction  \
# 0                57.877857                        0.311140
# 1                10.829943                        0.175592
# 2                 5.091079                        0.805153
# 3                 2.247564                        5.600044
# 4                44.190936                        0.566486
# ...                    ...                             ...
# 999995            2.207101                        0.112651
# 999996           19.872726                        2.683904
# 999997            2.914857                        1.472687
# 999998            4.258729                        0.242023
# 999999           58.108125                        0.318110
#
#         ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 0                             1.945940                1          1
# 1                             1.294219                1          0
# 2                             0.427715                1          0
# 3                             0.362663                1          1
# 4                             2.222767                1          1
# ...                                ...              ...        ...
# 999995                        1.626798                1          1
# 999996                        2.778303                1          1
# 999997                        0.218075                1          1
# 999998                        0.475822                1          0
# 999999                        0.386920                1          1
#
#         used_pin_number  online_order  fraud
# 0                     0             0      0
# 1                     0             0      0
# 2                     0             1      0
# 3                     0             1      0
# 4                     0             1      0
# ...                 ...           ...    ...
# 999995                0             0      0
# 999996                0             0      0
# 999997                0             1      0
# 999998                0             1      0
# 999999                0             1      0
#
# [912597 rows x 8 columns]

# %% [markdown]
# Getting fraud status

# %%
Yes_fraud = data[data['fraud'].isin([1])]   
No_fraud = data[data['fraud'].isin([0])]
t = len(Yes_fraud)
print('No. of frauds is : ' ,t)
f =len(No_fraud)
print('No. of no frauds is :  ',f )
# Out:
# No. of frauds is :  87403
# No. of no frauds is :   912597

# %% [markdown]
# # Cleaning Data

# %%
data.isnull().sum().head(10) #checking that no nulls
# Out:
# distance_from_home                0
# distance_from_last_transaction    0
# ratio_to_median_purchase_price    0
# repeat_retailer                   0
# used_chip                         0
# used_pin_number                   0
# online_order                      0
# fraud                             0
# dtype: int64

# %%
d_rows =   data[data.duplicated()]
print("Number of duplicated rows is:  ",d_rows.shape[0]) # check that no duplicates
# Out:
# Number of duplicated rows is:   0

# %% [markdown]
# # Scaling data

# %%
x = data.iloc[     :       ,          : -1]  # features
y = data.iloc[     :       ,            -1] #target
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %%
X[0]
# Out:
# array([ 0.47788202, -0.18284892,  0.04349141,  0.36658372,  1.36157608,
#        -0.33445812, -1.36442519])

# %% [markdown]
# # Splitting data

# %%
print(data.columns)
# Out:
# Index(['distance_from_home', 'distance_from_last_transaction',
#        'ratio_to_median_purchase_price', 'repeat_retailer', 'used_chip',
#        'used_pin_number', 'online_order', 'fraud'],
#       dtype='object')

# %%
x.head().style.set_properties(**{'background-color': 'black', 'color': 'lawngreen', 'border-color': 'Black'})
# Out:
# <style type="text/css">
# #T_10e8d_row0_col0, #T_10e8d_row0_col1, #T_10e8d_row0_col2, #T_10e8d_row0_col3, #T_10e8d_row0_col4, #T_10e8d_row0_col5, #T_10e8d_row0_col6, #T_10e8d_row1_col0, #T_10e8d_row1_col1, #T_10e8d_row1_col2, #T_10e8d_row1_col3, #T_10e8d_row1_col4, #T_10e8d_row1_col5, #T_10e8d_row1_col6, #T_10e8d_row2_col0, #T_10e8d_row2_col1, #T_10e8d_row2_col2, #T_10e8d_row2_col3, #T_10e8d_row2_col4, #T_10e8d_row2_col5, #T_10e8d_row2_col6, #T_10e8d_row3_col0, #T_10e8d_row3_col1, #T_10e8d_row3_col2, #T_10e8d_row3_col3, #T_10e8d_row3_col4, #T_10e8d_row3_col5, #T_10e8d_row3_col6, #T_10e8d_row4_col0, #T_10e8d_row4_col1, #T_10e8d_row4_col2, #T_10e8d_row4_col3, #T_10e8d_row4_col4, #T_10e8d_row4_col5, #T_10e8d_row4_col6 {
#   background-color: black;
#   color: lawngreen;
#   border-color: Black;
# }
# </style>
# <table id="T_10e8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10e8d_level0_col0" class="col_heading level0 col0" >distance_from_home</th>
#       <th id="T_10e8d_level0_col1" class="col_heading level0 col1" >distance_from_last_transaction</th>
#       <th id="T_10e8d_level0_col2" class="col_heading level0 col2" >ratio_to_median_purchase_price</th>
#       <th id="T_10e8d_level0_col3" class="col_heading level0 col3" >repeat_retailer</th>
#       <th id="T_10e8d_level0_col4" class="col_heading level0 col4" >used_chip</th>
#       <th id="T_10e8d_level0_col5" class="col_heading level0 col5" >used_pin_number</th>
#       <th id="T_10e8d_level0_col6" class="col_heading level0 col6" >online_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10e8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10e8d_row0_col0" class="data row0 col0" >57.877857</td>
#       <td id="T_10e8d_row0_col1" class="data row0 col1" >0.311140</td>
#       <td id="T_10e8d_row0_col2" class="data row0 col2" >1.945940</td>
#       <td id="T_10e8d_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_10e8d_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_10e8d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_10e8d_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_10e8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10e8d_row1_col0" class="data row1 col0" >10.829943</td>
#       <td id="T_10e8d_row1_col1" class="data row1 col1" >0.175592</td>
#       <td id="T_10e8d_row1_col2" class="data row1 col2" >1.294219</td>
#       <td id="T_10e8d_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_10e8d_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_10e8d_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_10e8d_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_10e8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10e8d_row2_col0" class="data row2 col0" >5.091079</td>
#       <td id="T_10e8d_row2_col1" class="data row2 col1" >0.805153</td>
#       <td id="T_10e8d_row2_col2" class="data row2 col2" >0.427715</td>
#       <td id="T_10e8d_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_10e8d_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_10e8d_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_10e8d_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_10e8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_10e8d_row3_col0" class="data row3 col0" >2.247564</td>
#       <td id="T_10e8d_row3_col1" class="data row3 col1" >5.600044</td>
#       <td id="T_10e8d_row3_col2" class="data row3 col2" >0.362663</td>
#       <td id="T_10e8d_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_10e8d_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_10e8d_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_10e8d_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_10e8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_10e8d_row4_col0" class="data row4 col0" >44.190936</td>
#       <td id="T_10e8d_row4_col1" class="data row4 col1" >0.566486</td>
#       <td id="T_10e8d_row4_col2" class="data row4 col2" >2.222767</td>
#       <td id="T_10e8d_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_10e8d_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_10e8d_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_10e8d_row4_col6" class="data row4 col6" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: fraud, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1000,shuffle = True )

# %%
X_train
# Out:
# array([[-0.37371294, -0.17602402,  0.1131036 , ..., -0.73444298,
#         -0.33445812, -1.36442519],
#        [-0.32698999, -0.1943799 ,  1.49059015, ..., -0.73444298,
#         -0.33445812,  0.73290937],
#        [-0.39464053, -0.18873961, -0.61800612, ..., -0.73444298,
#          2.98991094,  0.73290937],
#        ...,
#        [-0.23803865, -0.19363967,  0.541756  , ...,  1.36157608,
#         -0.33445812,  0.73290937],
#        [-0.02412254, -0.18737844, -0.41134796, ..., -0.73444298,
#         -0.33445812,  0.73290937],
#        [ 0.74918421, -0.09875855,  0.16277418, ...,  1.36157608,
#         -0.33445812,  0.73290937]])

# %%
 y_train
# Out:
# 802835    0
# 389960    1
# 819086    0
# 775244    0
# 688284    0
#          ..
# 376059    0
# 134848    1
# 71751     0
# 856663    0
# 107955    0
# Name: fraud, Length: 750000, dtype: int64

# %%
print('X_train is : ',X_train.shape)
print('X_test is : ',X_test.shape)
print('Y_train is : ',y_train.shape)
print('Y_test is : ',y_test.shape)
# Out:
# X_train is :  (750000, 7)
# X_test is :  (250000, 7)
# Y_train is :  (750000,)
# Y_test is :  (250000,)

# %% [markdown]
# # Data Analytics and Graphs

# %%
Fraud_Data = data["fraud"].value_counts()
Fraud_Data
# Out:
# 0    912597
# 1     87403
# Name: fraud, dtype: int64

# %% [markdown]
# 1) Bar Plot

# %%
plt.plot(figure = (25,25))
plt.title('Fraud vs Not_Fraud')
graph = sns.countplot(x = data["fraud"], palette = 'magma')
data.fraud.astype('category').value_counts()
# Out:
# 0    912597
# 1     87403
# Name: fraud, dtype: int64

# %%
R_Data = data["repeat_retailer"].value_counts()
R_Data
# Out:
# 1    881536
# 0    118464
# Name: repeat_retailer, dtype: int64

# %%
C_Data = data["used_chip"].value_counts()
C_Data
# Out:
# 0    649601
# 1    350399
# Name: used_chip, dtype: int64

# %%
P_Data = data["used_pin_number"].value_counts()
P_Data
# Out:
# 0    899392
# 1    100608
# Name: used_pin_number, dtype: int64

# %%
O_Data = data["online_order"].value_counts()
O_Data
# Out:
# 1    650552
# 0    349448
# Name: online_order, dtype: int64

# %%
plt.figure(figsize = (20,20))
plt.subplot(2,2,1)
sns.countplot(x = "repeat_retailer", palette = "Set2", data = data)

plt.subplot(2,2,2)
sns.countplot(x = "used_chip", palette = "Set2", data = data)

plt.subplot(2,2,3)
sns.countplot(x = "used_pin_number", palette = "Set2", data = data)

plt.subplot(2,2,4)
sns.countplot(x = "online_order", palette = "Set2", data  = data)
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# 2) Pie Plot

# %%
Data_Fraud = data["fraud"].value_counts()

Data_Fraud
# Out:
# 0    912597
# 1     87403
# Name: fraud, dtype: int64

# %%
plt.figure(figsize=(6,10))
Data_Fraud.plot(kind='pie', ylabel="", startangle=195, autopct='%1.1f%%',colors = ["skyblue", "firebrick"]
 ,labels = ['Not Fraud', 'Fraud'], explode = (0, 0.2), wedgeprops = {"edgecolor" : "black", "linewidth" : 1})

plt.legend(title="Credit Card:", loc="lower right")

plt.title("Credit Card Fraud Graph")
# Out:
# Text(0.5, 1.0, 'Credit Card Fraud Graph')

# %%
plt.figure(figsize = (20,20))

plt.subplot(2,2,1)
plt.pie(data["repeat_retailer"].value_counts(), labels = ("Yes", "No"), autopct = "%.2f%%", explode = (0, 0.1),colors = ["#808080", "#E9DCC9"])
plt.title("Did the credit card used at same retailer?")

plt.subplot(2,2,2)
plt.pie(data["used_chip"].value_counts(), labels = ("Yes", "No") , autopct = "%.2f%%", explode = (0, 0.1),
        colors = ["#808080", "#E9DCC9"])
plt.title("Did the credit card chip used?")

plt.subplot(2,2,3)
plt.pie(data["used_pin_number"].value_counts(), labels = ("Yes", "No"), autopct = "%.2f%%", explode = (0, 0.1),
        colors = ["#808080", "#E9DCC9"])
plt.title("Did the credit card pin number used?")

plt.subplot(2,2,4)
plt.pie(data["online_order"].value_counts(), labels = ("Yes", "No"), autopct = "%.2f%%", explode = (0, 0.1),
        colors = ["#808080", "#E9DCC9"])
plt.title("Was the transaction online?")
# Out:
# Text(0.5, 1.0, 'Was the transaction online?')

# %% [markdown]
# # Models

# %% [markdown]
# Decision Tree

# %%
treemodel = DecisionTreeClassifier()
parameter= { 'criterion' :['gini','entropy', 'log_loss'] , 'max_depth' :[1,2,3,4,5] } #calculation Method

# %%
from sklearn.model_selection import GridSearchCV # test every calculation method
cv = GridSearchCV(treemodel,parameter,scoring='accuracy',cv=5)

# %%
cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5]},
#              scoring='accuracy')

# %%
cv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5}

# %%
y_predtree=cv.predict(X_test)

# %%
print("Accuracy is ",(accuracy_score(y_test,y_predtree)))
# Out:
# Accuracy is  0.999004

# %% [markdown]
#  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression # Importing Logistic Regression

# %%
LR = LogisticRegression(max_iter = 200)
LR.fit(X_train, y_train)
y_predLR = LR.predict(X_test)
print("Accuracy is ",(accuracy_score(y_test,y_predLR)))
# Out:
# Accuracy is  0.959164

# %%
models = ["Logistic Regression", "Decision Tree"] # array carries models name

# %%
accuracy = [LR.score(X_test, y_test), metrics.accuracy_score(y_test, y_predtree)] # array carries accuracy scores

# %%
Table_of_Models = []
Table_of_Models = pd.DataFrame(models, columns=["    Model   Name     "])
Table_of_Models["Accuracy"] = accuracy
Table_of_Models.style.set_properties(**{'background-color': 'black', 'color': 'lawngreen', 'border-color': 'Black'})
# Out:
# <style type="text/css">
# #T_ea7ff_row0_col0, #T_ea7ff_row0_col1, #T_ea7ff_row1_col0, #T_ea7ff_row1_col1 {
#   background-color: black;
#   color: lawngreen;
#   border-color: Black;
# }
# </style>
# <table id="T_ea7ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea7ff_level0_col0" class="col_heading level0 col0" >    Model   Name     </th>
#       <th id="T_ea7ff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea7ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea7ff_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_ea7ff_row0_col1" class="data row0 col1" >0.959164</td>
#     </tr>
#     <tr>
#       <th id="T_ea7ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea7ff_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_ea7ff_row1_col1" class="data row1 col1" >0.999004</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# According to the table of models we see that Decision Tree accuracy is better than logistic regression.
